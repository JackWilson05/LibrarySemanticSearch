# %% [markdown]
# # Dataset Analysis and Planning
# - Dist of similarity w sd lines
# - length of descriptions dist (chars)

# %% [markdown]
# # Basic Retrieval (no rerank or finetuning)

# %% [markdown]
# # Ideas for upgrading retrieval
# - multi turn question answer refinement of query
# - reranking
# - finetuning
